# %%
print("Select Equation to Solve")
print("1. Quadratic Equation")
print("2. Cubic Equation")
print("3. Quartic Equation")


choice = int(input("Enter your choice: "))

if choice == 1:
    print("Quadratic Equation: Ax^2 + Bx + C = 0")
    A = float(input("Enter A: "))
    B = float(input("Enter B: "))
    C = float(input("Enter C: "))

    D = B**2 - 4*A*C

    root1 = (-B + D**0.5) / (2*A)
    root2 = (-B - D**0.5) / (2*A)

    print("Root 1 =", root1)
    print("Root 2 =", root2)

elif choice == 2:
    print("Cubic Equation: Ax^3 + Bx^2 + Cx + D = 0")

    A = float(input("Enter A: "))
    B = float(input("Enter B: "))
    C = float(input("Enter C: "))
    D = float(input("Enter D: "))

    coeff = [A, B, C, D]
    roots = np.roots(coeff)

    print("The roots are:", roots)

elif choice == 3:
    print("Quartic Equation: Ax^4 + Bx^3 + Cx^2 + Dx + E = 0")

    A = float(input("Enter A: "))
    B = float(input("Enter B: "))
    C = float(input("Enter C: "))
    D = float(input("Enter D: "))
    E = float(input("Enter E: "))

    coeff = [A, B, C, D, E]
    roots = np.roots(coeff)

    print("The roots are:", roots)

else:
    print("Invalid choice")
# Out:
# Select Equation to Solve
# 1. Quadratic Equation
# 2. Cubic Equation
# 3. Quartic Equation
# Enter your choice:  1
# Quadratic Equation: Ax^2 + Bx + C = 0
# Enter A:  7
# Enter B:  9
# Enter C:  7
# Root 1 = (-0.6428571428571429+0.7659860924831149j)
# Root 2 = (-0.6428571428571429-0.7659860924831149j)
