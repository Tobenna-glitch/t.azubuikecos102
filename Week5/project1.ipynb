# %%
class Employee:
    Employees = ["Mary Evans", "Eyo Ishan", "Durojaiye Dare", "Adams Ali", "Andrew Ugwu", "Stella Mankinde", "Jane Akibo", "Ago James", "Michell Taiwo", "Abraham Jones" , "Nicole Anide", "Kosi Korso", "Adele Martins", "Emmanuel Ojo", "Ajayi Fatima"]
    Tasks = ["Loading", "Transporting", "Reveiwing Orders", "Customer Service", "Delivering Items"]

# %%
import random

class employee:
    def __init__(self, name):
        self.name = name

    def check_employees(self):
        return self.name in employees

    def take_attendance(self):
        return f"Attendance taken for  {self.name}"

    def assign_task(self):
        task = random.choice(tasks)
        print("Task assigned {task}")

    def refuse_access(self):
        print("Access denied. You are not an employee")

# %%
import tkinter as tk

def process():
    name = entry.get()
    emp = Employee(name)

    if emp.check_employee():
        result.set(emp.take_attendance() + "\n" + emp.assign_task())
    else:
        result.set(emp.refuse_access())

# GUI Window
root = tk.Tk()
root.title("Employee System")

# Input Label
tk.Label(root, text="Enter your name:").pack()

# Input Box
entry = tk.Entry(root)
entry.pack()

# Result Display
result = tk.StringVar()
tk.Label(root, textvariable=result).pack()

# Button
tk.Button(root, text="Submit", command=process).pack()

root.mainloop()
